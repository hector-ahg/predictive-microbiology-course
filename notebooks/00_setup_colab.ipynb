# %% [markdown]
# # Set up notebook
#
# This notebook will clone our course GitHub repository ( predictive-microbiology-course) to Google Colab. This will ensure that we work with the same folder structure. It will also install the Python requirements for the following notebooks.

# %%
# 1. Clone GitHub repo to Colab
REPO_URL = "https://github.com/hector-ahg/predictive-microbiology-course.git"

# !git clone $REPO_URL
# %cd predictive-microbiology-course
# Out:
# Cloning into 'predictive-microbiology-course'...
# remote: Enumerating objects: 86, done.
# remote: Total 86 (delta 0), reused 0 (delta 0), pack-reused 86 (from 1)
# Receiving objects: 100% (86/86), 50.97 MiB | 31.90 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/predictive-microbiology-course

# %%
# List files
# !ls
# Out:
# data_links.md  docs	notebooks  raw_results	requirements.txt
# dataset        figures	pipeline   README.md

# %%
# Check if notebooks are found
# !find notebooks -maxdepth 2
# Out:
# notebooks
# notebooks/00_metadata_exploration.ipynb
# notebooks/00_download_products.ipynb
# notebooks/01_introduction_python.ipynb
# notebooks/00_download_sequences.ipynb
# notebooks/12_predictive_microbial_ecology.ipynb
# notebooks/02_qiime2_manifest.ipynb
# notebooks/11_metadata_integration_and_clustering.ipynb
# notebooks/10_descriptive_statistics.ipynb

# %% [markdown]
# ### Install dependencies
#
# Before running the notebooks, it's a good practice to install all required Python packages. These are listed in `requirements.txt`.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Now we are ready to for the fun!
# To run the following notebook:
# 1. Click "File"
# 2. Click "Open Notebook"
# 3. Click "GitHub"
# 4. Search for  https://github.com/hector-ahg/predictive-microbiology-course
# 5. Click ""
